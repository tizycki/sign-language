# %%
from utils.images_from_video import video_to_images
import os
import cv2

# %%
input_dir_path = './data/video_raw/'
output_dir_path = './data/video_frames/'
file_names=[
    # 'internal_resource_2323.MOV'
    # 'internal_resource_2328.MOV'
    #'internal_resource_2334.MOV',
    'internal_resource_2337.MOV'
]

# %%
for file_name in file_names:
    file_path = os.path.join(input_dir_path, file_name)
    
    file_name = file_name.split('.')[0]
    
    video_to_images(
        video_path=file_path,
        output_dir=output_dir_path,
        file_name_prefix=file_name, 
        output_fps=10,
        rotate=True,
        create_subdir=True,
        start_frame=100,
        end_frame=-1
    )
# Out:
# Input video info:
# Input FPS: 59.96367585020612
# Duration: 1214
# Create output sub-folder: internal_resource_2337_fps10 in output_directory: ./data/video_frames/
# Processing frame of index: 000000 / ~012140.             Frame read status: True
# Frame skipped.
# Processing frame of index: 000001 / ~012140.             Frame read status: True
# Frame skipped.
# Processing frame of index: 000002 / ~012140.             Frame read status: True
# Frame skipped.
# Processing frame of index: 000003 / ~012140.             Frame read status: True
# Frame skipped.
# Processing frame of index: 000004 / ~012140.             Frame read status: True
# Frame skipped.
# Processing frame of index: 000005 / ~012140.             Frame read status: True
# Frame skipped.
# Processing frame of index: 000006 / ~012140.             Frame read status: True
# Frame skipped.
# Processing frame of index: 000007 / ~012140.             Frame read status: True
# Frame skipped.
# ...
